# %%
import pandas as pd
# importing frailty data
frailty_raw_data = pd.read_csv('/content/frailty/data_raw/frailty_raw_data.csv')
frailty_raw_data
# Out:
#    Height (Inches)  Weight (Pounds)   Age  Grip strength Frailty
# 0             65.8               112   30             30       N
# 1             71.5               136   19             31       N
# 2             69.4               153   45             29       N
# 3             68.2               142   22             28       Y
# 4             67.8               144   29             24       Y
# 5             68.7               123   50             26       N
# 6             69.8               141   51             22       Y
# 7             70.1               136   23             20       Y
# 8             67.9               112   17             19       N
# 9             66.8               120   39             31       N

# %%
#Preprocessing the data
#Updated the column names
frailty_raw_data.columns = ['Height(in)', 'Weight(lb)', 'Age', 'Grip_Strength(kg)', 'Frailty']

#Replaced the categorical values of Frailty column with numerical values
frailty_raw_data['Frailty'].replace(['Y', 'N'], [0,1], inplace=True)

# %%
frailty_raw_data
# Out:
#    Height(in)  Weight(lb)  Age  Grip_Strength(kg)  Frailty
# 0        65.8         112   30                 30        1
# 1        71.5         136   19                 31        1
# 2        69.4         153   45                 29        1
# 3        68.2         142   22                 28        0
# 4        67.8         144   29                 24        0
# 5        68.7         123   50                 26        1
# 6        69.8         141   51                 22        0
# 7        70.1         136   23                 20        0
# 8        67.9         112   17                 19        1
# 9        66.8         120   39                 31        1

# %%
#Creating the cleaned df from the preprocessed data
frailty_clean_data = frailty_raw_data

# %%
#Printing cleaned dataframe
frailty_clean_data
# Out:
#    Height(in)  Weight(lb)  Age  Grip_Strength(kg)  Frailty
# 0        65.8         112   30                 30        1
# 1        71.5         136   19                 31        1
# 2        69.4         153   45                 29        1
# 3        68.2         142   22                 28        0
# 4        67.8         144   29                 24        0
# 5        68.7         123   50                 26        1
# 6        69.8         141   51                 22        0
# 7        70.1         136   23                 20        0
# 8        67.9         112   17                 19        1
# 9        66.8         120   39                 31        1

# %%
#Saving cleaned data into a csv file
frailty_clean_data.to_csv('/content/frailty/data_clean/frailty_clean_data.csv')
